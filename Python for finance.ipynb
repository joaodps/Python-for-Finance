# %%
### Python for Finance ### Data-COFINA.LS

#import datetime as dt
#import matplotlib.pyplot as plt
#from matplotlib import style
#import pandas as pd 
#import pandas_datareader.data as web
#from mpl_finance import candlestick_ohlc
#import matplotlib.dates as mdates
#
#style.use('ggplot')
#
#start=dt.datetime(2000,1,1)
#end=dt.datetime(2019,10,10)
#
#df=web.DataReader('CFN.LS','yahoo',start,end)
#df.plot()
#df.show()
#df.to_csv()
#
#df=pd.read_csv('cfn.csv', parse_dates=True, index_col=0)

# %%
#print(df.head())
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2000-01-03  0.9120  0.8860  0.8860  0.9075  649840.0   0.616150
# 2000-01-04  0.9115  0.8265  0.9115  0.8705  465040.0   0.591029
# 2000-01-05  0.8705  0.8325  0.8605  0.8500   82680.0   0.577110
# 2000-01-06  0.9050  0.8605  0.8605  0.9000  261200.0   0.611058
# 2000-01-07  0.9115  0.8820  0.8855  0.9050  218040.0   0.614452

# %%
#df['100ma']= df['Adj Close'].rolling(window=100).mean()

#print(df.tail())
# Out:
#              High    Low   Open  Close    Volume  Adj Close    100ma
# Date
# 2019-10-07  0.409  0.400  0.400  0.409  258175.0      0.409  0.47272
# 2019-10-08  0.408  0.395  0.405  0.399   75403.0      0.399  0.47193
# 2019-10-09  0.408  0.360  0.395  0.366  394717.0      0.366  0.47084
# 2019-10-10  0.385  0.326  0.373  0.380  620813.0      0.380  0.46992
# 2019-10-11  0.380  0.367  0.380  0.368   85641.0      0.368  0.46896

# %%
#ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
#ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1)

#ax1.plot(df.index, df['Adj Close'])
#ax1.plot(df.index, df['100ma'])
#ax2.bar(df.index, df['Volume'])
#plt.show()
# Out:
# C:\Users\joaod\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#df_ohlc= df['Adj Close'].resample('10D').ohlc()
#df_volume= df['Volume'].resample('10D').sum()
#print(df_ohlc.head())
# Out:
#                 open      high       low     close
# Date
# 2000-01-03  0.616150  0.616150  0.577110  0.607663
# 2000-01-13  0.601213  0.675558  0.601213  0.675558
# 2000-01-23  0.645005  0.645684  0.616489  0.630068
# 2000-02-02  0.655190  1.347722  0.655190  1.347722
# 2000-02-12  1.268624  1.268624  1.098546  1.240447

# %%
#df_ohlc= df['Adj Close'].resample('10D').ohlc()
#df_volume= df['Volume'].resample('10D').sum()

#df_ohlc.reset_index(inplace=True)
#df_ohlc['Date']=df_ohlc['Date'].map(mdates.date2num)

#ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
#ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1)
#ax1.xaxis_date()

#candlestick_ohlc(ax1,df_ohlc.values, width=2, colorup='g')
#ax2.fill_between(df_volume.index.map(mdates.date2num),df_volume.values, 0)
#plt.show()
#episode4
# Out:
# C:\Users\joaod\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#episode 5
